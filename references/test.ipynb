# %%
import pandas as pd
import numpy as np
from gurobipy import Model, GRB

# %%
df = pd.read_csv('data/med_inv_dataset.csv') # For local

df.columns = df.columns.str.lower()
df = df.dropna()
df['dateofbill'] = pd.to_datetime(df['dateofbill'])
df['month_name'] = df['dateofbill'].dt.strftime('%B') # Extract month name
df['month_number'] = df['dateofbill'].dt.month  # Extract month number
df['week_number'] = df['dateofbill'].dt.isocalendar().week  # Extract week number
df.sample(5)
# Out:
#       typeofsales   patient_id    specialisation         dept dateofbill  \
# 11735        Sale  12018079461   Specialisation7  Department1 2022-09-02
# 10227        Sale  12018107236  Specialisation16  Department1 2022-08-14
# 8441         Sale  12018076747   Specialisation4  Department1 2022-04-15
# 1870         Sale  12018095967   Specialisation7  Department1 2022-06-05
# 7622         Sale  12018068793  Specialisation33  Department2 2022-08-03
#
#        quantity  returnquantity  final_cost  final_sales  rtnmrp formulation  \
# 11735         1               0      46.676       47.584     0.0       Form1
# 10227         2               0      47.754      104.204     0.0       Form1
# 8441          1               0      95.020      106.760     0.0       Form1
# 1870          1               0      62.494       71.000     0.0       Form1
# 7622          1               0      44.368       45.500     0.0       Form1
#
#                                                 drugname  \
# 11735                          SODIUM CHLORIDE IVF 100ML
# 10227                                    CEFTRIAXONE 1GM
# 8441                     MYCOPHENOLATE MOFETIL 250MG CAP
# 1870   ANHYDROUS DEXTROSE 1000MG + ASCORBIC ACID 500M...
# 7622                                     BUPIVACAINE 5MG
#
#                              subcat                                subcat1  \
# 11735  IV FLUIDS, ELECTROLYTES, TPN  INTRAVENOUS & OTHER STERILE SOLUTIONS
# 10227                    INJECTIONS                        ANTI-INFECTIVES
# 8441             TABLETS & CAPSULES                             IMMUNOLOGY
# 1870                     INJECTIONS                    VITAMINS & MINERALS
# 7622                     INJECTIONS                           ANAESTHETICS
#
#       month_name  month_number  week_number
# 11735  September             9           35
# 10227     August             8           32
# 8441       April             4           15
# 1870        June             6           22
# 7622      August             8           31

# %%
# Create a bi-weekly period column
df['bi_weekly'] = (df['dateofbill'].dt.day - 1) // 14 + 1

# Group by drug, subcat, month_name, month_number, and bi-weekly period
df_bi_weekly = df.groupby(['drugname', 'subcat', 'month_name', 'month_number', 'bi_weekly'], as_index=False).agg(
    {
        'quantity': 'sum',
        'returnquantity': 'sum',
        'final_cost': 'sum',
        'final_sales': 'sum',
        'rtnmrp': 'sum'
    }
)

df_bi_weekly.head()
# Out:
#                    drugname              subcat month_name  month_number  \
# 0  ACEBROPHYLLINE 100MG CAP  TABLETS & CAPSULES     August             8
# 1  ACEBROPHYLLINE 100MG CAP  TABLETS & CAPSULES        May             5
# 2  ACEBROPHYLLINE 200MG TAB  TABLETS & CAPSULES      April             4
# 3  ACEBROPHYLLINE 200MG TAB  TABLETS & CAPSULES     August             8
# 4  ACEBROPHYLLINE 200MG TAB  TABLETS & CAPSULES   December            12
#
#    bi_weekly  quantity  returnquantity  final_cost  final_sales  rtnmrp
# 0          1         1               0      64.622        72.40     0.0
# 1          2         1               0      62.766        69.64     0.0
# 2          3         0               1      76.800         0.00    86.0
# 3          2         2               0     149.924       172.00     0.0
# 4          1         1               0      74.962        86.00     0.0

# %%
# Step 1: Collect top 5 subcategories with the highest sum of quantity
top_5_subcats = df_bi_weekly.groupby('subcat')['quantity'].sum().nlargest(5).index

# Step 2: Filter the dataframe for only the top 5 subcategories
filtered_top_5_per_subcat = df_bi_weekly[df_bi_weekly['subcat'].isin(top_5_subcats)]

# Step 3: Aggregate quantity sum grouping by subcat and drugname
top_5_drugs_per_subcat = (
    filtered_top_5_per_subcat.groupby(['subcat', 'drugname'])['quantity']
    .sum()
    .reset_index()
    .sort_values(['subcat', 'quantity'], ascending=[True, False])
    .groupby('subcat')
    .head(5)
)

top_5_drugs_per_subcat
# Out:
#                            subcat  \
# 9             INHALERS & RESPULES
# 11            INHALERS & RESPULES
# 2             INHALERS & RESPULES
# 6             INHALERS & RESPULES
# 7             INHALERS & RESPULES
# 185                    INJECTIONS
# 243                    INJECTIONS
# 192                    INJECTIONS
# 195                    INJECTIONS
# 182                    INJECTIONS
# 270  IV FLUIDS, ELECTROLYTES, TPN
# 266  IV FLUIDS, ELECTROLYTES, TPN
# 261  IV FLUIDS, ELECTROLYTES, TPN
# 267  IV FLUIDS, ELECTROLYTES, TPN
# 254  IV FLUIDS, ELECTROLYTES, TPN
# 284           LIQUIDS & SOLUTIONS
# 283           LIQUIDS & SOLUTIONS
# 274           LIQUIDS & SOLUTIONS
# 285           LIQUIDS & SOLUTIONS
# 278           LIQUIDS & SOLUTIONS
# 601            TABLETS & CAPSULES
# 598            TABLETS & CAPSULES
# 569            TABLETS & CAPSULES
# 381            TABLETS & CAPSULES
# 510            TABLETS & CAPSULES
#
#                                               drugname  quantity
# 9          LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES       604
# 11                                    SALBUTAMOL 2.5MG       285
# 2                                       BUDESONIDE 2ML       169
# 6    LEVOSALBUTAMOL 1.25MG + IPRATROPIUM BROMIDE 50...       169
# 7                       LEVOSALBUTAMOL 1.25MG RESPULES        85
# 185                                 ONDANSETRON 2MG/ML       933
# 243                  WATER FOR INJECTION 10ML SOLUTION       871
# 192                              PANTOPRAZOLE 40MG INJ       594
# 195                             PARACETAMOL 1GM IV INJ       593
# 182                              NORADRENALINE 2ML INJ       553
# 270                          SODIUM CHLORIDE IVF 100ML      1278
# 266                               SODIUM CHLORIDE 0.9%       942
# 261                    MULTIPLE ELECTROLYTES 500ML IVF       919
# 267                    SODIUM CHLORIDE 0.9% IVF 1000ML       202
# 254                              HUMAN ALBUMIN 25% INJ       199
# 284                                 SEVOFLURANE 99.97%      1193
# 283                                        SEVOFLURANE       470
# 274                    CHLORHEXIDINE GLUCONATE 0.2%W/V        57
# 285                    SODIUM PHOSPHATE 1.963GM POWDER        53
# 278                                LACTULOSE 300ML SYP        50
# 601                           VALGANCICLOVIR 450MG TAB       134
# 598                     URSODEOXYCHOLIC ACID 300MG TAB        58
# 569                                 TACROLIMUS 1MG CAP        54
# 381                                  ESOMEPRAZOLE 40MG        42
# 510                              PANTOPRAZOLE 40MG TAB        39

# %%
filtered_df_bi_weekly = df_bi_weekly.merge(top_5_drugs_per_subcat[['subcat', 'drugname']], on=['subcat', 'drugname'])
filtered_df_bi_weekly = filtered_df_bi_weekly.sort_values(by=['subcat', 'drugname', 'month_number', 'bi_weekly'])
# Add a biweekly index for every drugname in every subcat
filtered_df_bi_weekly['biweekly_index'] = (
    filtered_df_bi_weekly.groupby(['subcat', 'drugname'])
    .cumcount() + 1
)
filtered_df_bi_weekly
# Out:
#                      drugname               subcat month_name  month_number  \
# 11             BUDESONIDE 2ML  INHALERS & RESPULES    January             1
# 12             BUDESONIDE 2ML  INHALERS & RESPULES    January             1
# 13             BUDESONIDE 2ML  INHALERS & RESPULES    January             1
# 9              BUDESONIDE 2ML  INHALERS & RESPULES   February             2
# 10             BUDESONIDE 2ML  INHALERS & RESPULES   February             2
# ..                        ...                  ...        ...           ...
# 631  VALGANCICLOVIR 450MG TAB   TABLETS & CAPSULES  September             9
# 632  VALGANCICLOVIR 450MG TAB   TABLETS & CAPSULES  September             9
# 630  VALGANCICLOVIR 450MG TAB   TABLETS & CAPSULES    October            10
# 628  VALGANCICLOVIR 450MG TAB   TABLETS & CAPSULES   November            11
# 629  VALGANCICLOVIR 450MG TAB   TABLETS & CAPSULES   November            11
#
#      bi_weekly  quantity  returnquantity  final_cost  final_sales   rtnmrp  \
# 11           1         6               0     142.856      268.668    0.000
# 12           2        15               0     217.322      671.670    0.000
# 13           3        12               0     165.858      537.336    0.000
# 9            1         6               2     190.470      270.210   90.584
# 10           2         3               0      91.464      134.334    0.000
# ..         ...       ...             ...         ...          ...      ...
# 631          1         6               0     748.114     1039.992    0.000
# 632          2         4               0     485.410      693.328    0.000
# 630          1         9               0    1082.174     1559.988    0.000
# 628          1        11               1    1456.230     1906.652  173.332
# 629          2         6               0     748.116     1039.992    0.000
#
#      biweekly_index
# 11                1
# 12                2
# 13                3
# 9                 4
# 10                5
# ..              ...
# 631              14
# 632              15
# 630              16
# 628              17
# 629              18
#
# [665 rows x 11 columns]

# %%
subcat_drug_dict = top_5_drugs_per_subcat.groupby('subcat')['drugname'].apply(list).to_dict()
subcat_drug_dict
# Out:
# {'INHALERS & RESPULES': ['LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES',
#   'SALBUTAMOL 2.5MG',
#   'BUDESONIDE 2ML',
#   'LEVOSALBUTAMOL 1.25MG + IPRATROPIUM BROMIDE 500MCG RESPULES',
#   'LEVOSALBUTAMOL 1.25MG RESPULES'],
#  'INJECTIONS': ['ONDANSETRON 2MG/ML',
#   'WATER FOR INJECTION 10ML SOLUTION',
#   'PANTOPRAZOLE 40MG INJ',
#   'PARACETAMOL 1GM IV INJ',
#   'NORADRENALINE 2ML INJ'],
#  'IV FLUIDS, ELECTROLYTES, TPN': ['SODIUM CHLORIDE IVF 100ML',
#   'SODIUM CHLORIDE 0.9%',
#   'MULTIPLE ELECTROLYTES 500ML IVF',
#   'SODIUM CHLORIDE 0.9% IVF 1000ML',
#   'HUMAN ALBUMIN 25% INJ'],
#  'LIQUIDS & SOLUTIONS': ['SEVOFLURANE 99.97%',
#   'SEVOFLURANE',
#   'CHLORHEXIDINE GLUCONATE 0.2%W/V',
#   'SODIUM PHOSPHATE 1.963GM POWDER',
#   'LACTULOSE 300ML SYP'],
#  'TABLETS & CAPSULES': ['VALGANCICLOVIR 450MG TAB',
#   'URSODEOXYCHOLIC ACID 300MG TAB',
#   'TACROLIMUS 1MG CAP',
#   'ESOMEPRAZOLE 40MG',
#   'PANTOPRAZOLE 40MG TAB']}

# %%
def calculate_last_three_cycles(df, subcat, drugname, horizon = 'biweekly_index', quanity= 'quantity', all_filter = False, code = False):
  ml_df = df[(df['subcat'] == subcat) & (df['drugname'] == drugname)][[horizon,'drugname', 'subcat', quanity]]

  ml_df['quantity_lastcycle']=ml_df[quanity].shift(+1)
  ml_df['quantity_2cycleback']=ml_df[quanity].shift(+2)
  ml_df['quantity_3cycleback']=ml_df[quanity].shift(+3)
  ml_df['quantity_4cycleback']=ml_df[quanity].shift(+4)
  ml_df['quantity_5cycleback']=ml_df[quanity].shift(+5)

  ml_df = ml_df.dropna() #dropping na is necessary to avoid model failure other option

  X = ml_df[['subcat','drugname', horizon,'quantity_lastcycle', 'quantity_2cycleback', 'quantity_3cycleback', 'quantity_4cycleback', 'quantity_5cycleback']]
  y = ml_df[quanity]
  return X, y

# %%
# Filter rows where month_number is 4, 5, or 6
filtered_months_df = filtered_df_bi_weekly[filtered_df_bi_weekly['month_number'].isin([4, 5, 6])]

# The rest of the DataFrame
rest_df = filtered_df_bi_weekly[~filtered_df_bi_weekly['month_number'].isin([4, 5, 6])]

# %%
filtered_months_df.shape
# Out:
# (156, 11)

# %%
rest_df.shape
# Out:
# (509, 11)

# %%
trainX = pd.DataFrame(columns=['subcat', 'drugname','quantity_lastcycle', 'quantity_2cycleback', 'quantity_3cycleback',
                              'quantity_4cycleback','quantity_5cycleback'])
for key in subcat_drug_dict.keys():
    for drug in subcat_drug_dict[key]:
        # print(key, drug)
        X, y = calculate_last_three_cycles(rest_df, subcat = key, drugname=drug, quanity = 'quantity', all_filter = False, code = False)
        trainX = pd.concat([X, trainX])
# Out:
# /var/folders/dc/n7cp43k94blc5lmsv8p725pc0000gn/T/ipykernel_14606/3078485149.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   trainX = pd.concat([X, trainX])

# %%
trainX
# Out:
#                   subcat                                     drugname  \
# 349   TABLETS & CAPSULES                        PANTOPRAZOLE 40MG TAB
# 344   TABLETS & CAPSULES                        PANTOPRAZOLE 40MG TAB
# 336   TABLETS & CAPSULES                        PANTOPRAZOLE 40MG TAB
# 337   TABLETS & CAPSULES                        PANTOPRAZOLE 40MG TAB
# 355   TABLETS & CAPSULES                        PANTOPRAZOLE 40MG TAB
# ..                   ...                                          ...
# 197  INHALERS & RESPULES  LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES
# 198  INHALERS & RESPULES  LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES
# 179  INHALERS & RESPULES  LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES
# 180  INHALERS & RESPULES  LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES
# 181  INHALERS & RESPULES  LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES
#
#      biweekly_index  quantity_lastcycle  quantity_2cycleback  \
# 349             6.0                 3.0                  1.0
# 344            10.0                 1.0                  3.0
# 336            11.0                 4.0                  1.0
# 337            12.0                 2.0                  4.0
# 355            13.0                 1.0                  2.0
# ..              ...                 ...                  ...
# 197            27.0                49.0                 12.0
# 198            28.0                27.0                 49.0
# 179            29.0                11.0                 27.0
# 180            30.0                 0.0                 11.0
# 181            31.0                40.0                  0.0
#
#      quantity_3cycleback  quantity_4cycleback  quantity_5cycleback
# 349                  1.0                  5.0                  2.0
# 344                  1.0                  1.0                  5.0
# 336                  3.0                  1.0                  1.0
# 337                  1.0                  3.0                  1.0
# 355                  4.0                  1.0                  3.0
# ..                   ...                  ...                  ...
# 197                 14.0                 10.0                  5.0
# 198                 12.0                 14.0                 10.0
# 179                 49.0                 12.0                 14.0
# 180                 27.0                 49.0                 12.0
# 181                 11.0                 27.0                 49.0
#
# [384 rows x 8 columns]

# %%
testX = pd.DataFrame(columns=['subcat', 'drugname','quantity_lastcycle', 'quantity_2cycleback', 'quantity_3cycleback',
                              'quantity_4cycleback','quantity_5cycleback'])
for key in subcat_drug_dict.keys():
    for drug in subcat_drug_dict[key]:
        # print(key, drug)
        X, y = calculate_last_three_cycles(filtered_months_df, subcat = key, drugname=drug, quanity = 'quantity', all_filter = False, code = False)
        testX = pd.concat([X, testX])
        # break
    # break
# Out:
# /var/folders/dc/n7cp43k94blc5lmsv8p725pc0000gn/T/ipykernel_14606/1020696423.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   testX = pd.concat([X, testX])

# %%
testX = testX.sort_values(by='biweekly_index')
testX
# Out:
#                            subcat  \
# 146           INHALERS & RESPULES
# 404           INHALERS & RESPULES
# 604            TABLETS & CAPSULES
# 497  IV FLUIDS, ELECTROLYTES, TPN
# 254                    INJECTIONS
# 191           INHALERS & RESPULES
# 556           LIQUIDS & SOLUTIONS
# 103  IV FLUIDS, ELECTROLYTES, TPN
# 17            INHALERS & RESPULES
# 292                    INJECTIONS
# 648                    INJECTIONS
# 326                    INJECTIONS
# 255                    INJECTIONS
# 557           LIQUIDS & SOLUTIONS
# 537  IV FLUIDS, ELECTROLYTES, TPN
# 96   IV FLUIDS, ELECTROLYTES, TPN
# 381                    INJECTIONS
# 47            LIQUIDS & SOLUTIONS
# 471  IV FLUIDS, ELECTROLYTES, TPN
# 230  IV FLUIDS, ELECTROLYTES, TPN
# 18            INHALERS & RESPULES
# 97   IV FLUIDS, ELECTROLYTES, TPN
# 285                    INJECTIONS
# 649                    INJECTIONS
# 222  IV FLUIDS, ELECTROLYTES, TPN
# 529  IV FLUIDS, ELECTROLYTES, TPN
# 373                    INJECTIONS
# 256                    INJECTIONS
# 464  IV FLUIDS, ELECTROLYTES, TPN
# 318                    INJECTIONS
# 223  IV FLUIDS, ELECTROLYTES, TPN
# 465  IV FLUIDS, ELECTROLYTES, TPN
# 319                    INJECTIONS
# 374                    INJECTIONS
# 286                    INJECTIONS
# 530  IV FLUIDS, ELECTROLYTES, TPN
# 320                    INJECTIONS
# 224  IV FLUIDS, ELECTROLYTES, TPN
# 531  IV FLUIDS, ELECTROLYTES, TPN
# 375                    INJECTIONS
#
#                                               drugname  biweekly_index  \
# 146  LEVOSALBUTAMOL 1.25MG + IPRATROPIUM BROMIDE 50...            12.0
# 404                                   SALBUTAMOL 2.5MG            12.0
# 604                     URSODEOXYCHOLIC ACID 300MG TAB            13.0
# 497                    SODIUM CHLORIDE 0.9% IVF 1000ML            13.0
# 254                              NORADRENALINE 2ML INJ            13.0
# 191        LEVOSALBUTAMOL/LEVALBUTEROL 0.63MG RESPULES            13.0
# 556                    SODIUM PHOSPHATE 1.963GM POWDER            13.0
# 103                              HUMAN ALBUMIN 25% INJ            13.0
# 17                                      BUDESONIDE 2ML            14.0
# 292                                 ONDANSETRON 2MG/ML            14.0
# 648                  WATER FOR INJECTION 10ML SOLUTION            14.0
# 326                              PANTOPRAZOLE 40MG INJ            14.0
# 255                              NORADRENALINE 2ML INJ            14.0
# 557                    SODIUM PHOSPHATE 1.963GM POWDER            14.0
# 537                          SODIUM CHLORIDE IVF 100ML            14.0
# 96                               HUMAN ALBUMIN 25% INJ            14.0
# 381                             PARACETAMOL 1GM IV INJ            14.0
# 47                     CHLORHEXIDINE GLUCONATE 0.2%W/V            14.0
# 471                               SODIUM CHLORIDE 0.9%            14.0
# 230                    MULTIPLE ELECTROLYTES 500ML IVF            14.0
# 18                                      BUDESONIDE 2ML            15.0
# 97                               HUMAN ALBUMIN 25% INJ            15.0
# 285                                 ONDANSETRON 2MG/ML            15.0
# 649                  WATER FOR INJECTION 10ML SOLUTION            15.0
# 222                    MULTIPLE ELECTROLYTES 500ML IVF            15.0
# 529                          SODIUM CHLORIDE IVF 100ML            15.0
# 373                             PARACETAMOL 1GM IV INJ            15.0
# 256                              NORADRENALINE 2ML INJ            15.0
# 464                               SODIUM CHLORIDE 0.9%            15.0
# 318                              PANTOPRAZOLE 40MG INJ            15.0
# 223                    MULTIPLE ELECTROLYTES 500ML IVF            16.0
# 465                               SODIUM CHLORIDE 0.9%            16.0
# 319                              PANTOPRAZOLE 40MG INJ            16.0
# 374                             PARACETAMOL 1GM IV INJ            16.0
# 286                                 ONDANSETRON 2MG/ML            16.0
# 530                          SODIUM CHLORIDE IVF 100ML            16.0
# 320                              PANTOPRAZOLE 40MG INJ            17.0
# 224                    MULTIPLE ELECTROLYTES 500ML IVF            17.0
# 531                          SODIUM CHLORIDE IVF 100ML            17.0
# 375                             PARACETAMOL 1GM IV INJ            17.0
#
#      quantity_lastcycle  quantity_2cycleback  quantity_3cycleback  \
# 146                 4.0                  9.0                  4.0
# 404                 3.0                 14.0                  1.0
# 604                 3.0                  3.0                  2.0
# 497                15.0                  3.0                 11.0
# 254                13.0                  3.0                 30.0
# 191                17.0                 28.0                 25.0
# 556                 1.0                  3.0                  2.0
# 103                10.0                  5.0                  2.0
# 17                 14.0                  4.0                  3.0
# 292                23.0                 31.0                  1.0
# 648                 5.0                 16.0                 29.0
# 326                23.0                 21.0                  3.0
# 255                56.0                 13.0                  3.0
# 557                 1.0                  1.0                  3.0
# 537                81.0                 40.0                 14.0
# 96                  1.0                 10.0                  5.0
# 381                11.0                 21.0                  6.0
# 47                  2.0                  1.0                  2.0
# 471                30.0                 36.0                  8.0
# 230                54.0                 50.0                  3.0
# 18                  4.0                 14.0                  4.0
# 97                  7.0                  1.0                 10.0
# 285                10.0                 23.0                 31.0
# 649                37.0                  5.0                 16.0
# 222                10.0                 54.0                 50.0
# 529                19.0                 81.0                 40.0
# 373                 7.0                 11.0                 21.0
# 256                 6.0                 56.0                 13.0
# 464                 1.0                 30.0                 36.0
# 318                 1.0                 23.0                 21.0
# 223                25.0                 10.0                 54.0
# 465                30.0                  1.0                 30.0
# 319                28.0                  1.0                 23.0
# 374                20.0                  7.0                 11.0
# 286                29.0                 10.0                 23.0
# 530                48.0                 19.0                 81.0
# 320                10.0                 28.0                  1.0
# 224                46.0                 25.0                 10.0
# 531                95.0                 48.0                 19.0
# 375                15.0                 20.0                  7.0
#
#      quantity_4cycleback  quantity_5cycleback
# 146                  5.0                 12.0
# 404                  2.0                  8.0
# 604                  2.0                  3.0
# 497                  8.0                  9.0
# 254                 10.0                 20.0
# 191                  5.0                 29.0
# 556                  3.0                  3.0
# 103                  6.0                 13.0
# 17                   1.0                  6.0
# 292                 28.0                 33.0
# 648                 23.0                 30.0
# 326                  8.0                 33.0
# 255                 30.0                 10.0
# 557                  2.0                  3.0
# 537                 89.0                 52.0
# 96                   2.0                  6.0
# 381                 21.0                 29.0
# 47                   1.0                  3.0
# 471                 41.0                 44.0
# 230                 29.0                 31.0
# 18                   3.0                  1.0
# 97                   5.0                  2.0
# 285                  1.0                 28.0
# 649                 29.0                 23.0
# 222                  3.0                 29.0
# 529                 14.0                 89.0
# 373                  6.0                 21.0
# 256                  3.0                 30.0
# 464                  8.0                 41.0
# 318                  3.0                  8.0
# 223                 50.0                  3.0
# 465                 36.0                  8.0
# 319                 21.0                  3.0
# 374                 21.0                  6.0
# 286                 31.0                  1.0
# 530                 40.0                 14.0
# 320                 23.0                 21.0
# 224                 54.0                 50.0
# 531                 81.0                 40.0
# 375                 11.0                 21.0

# %%
df.head()
# Out:
#    Day    Drug  Predicted_Demand  Unit_Cost  Salvage_Value  Return_Prediction  \
# 0    1  Drug A                43  33.690086       6.971516                  5
# 1    2  Drug A                33  44.924573       1.045554                  6
# 2    3  Drug A                19  26.249672       2.447272                  2
# 3    4  Drug A                47  10.381741       5.938604                  9
# 4    5  Drug A                12  37.096015       7.227057                  2
#
#    Shelf_Life
# 0          11
# 1          13
# 2          11
# 3           9
# 4          14

# %% [markdown]
# ## Final Consolidation

# %%
# Forecasted demand from Random Forest (example data for 30 days)
np.random.seed(42)
T = 30  # Planning horizon
drugs = ["Drug A", "Drug B", "Drug C", "Drug D"]

df = pd.DataFrame({
    "Day": np.tile(np.arange(1, T+1), len(drugs)),
    "Drug": np.repeat(drugs, T),
    "Predicted_Demand": np.random.randint(5, 50, T * len(drugs)),
    "Unit_Cost": np.random.uniform(5, 50, T * len(drugs)),  
    "Salvage_Value": np.random.uniform(1, 10, T * len(drugs)),  
    "Return_Prediction": np.random.randint(0, 10, T * len(drugs)),  
    "Shelf_Life": np.random.randint(5, 15, T * len(drugs))  
})

# %%
# Fix values per drug (same across all days)
fixed_values = {
    "Drug A": {"Unit_Cost": 20, "Salvage_Value": 5, "Shelf_Life": 10},
    "Drug B": {"Unit_Cost": 25, "Salvage_Value": 6, "Shelf_Life": 12},
    "Drug C": {"Unit_Cost": 30, "Salvage_Value": 7, "Shelf_Life": 15},
    "Drug D": {"Unit_Cost": 18, "Salvage_Value": 4, "Shelf_Life": 8},
}

# Apply fixed values to each row based on drug type
df["Unit_Cost"] = df["Drug"].map(lambda x: fixed_values[x]["Unit_Cost"])
df["Salvage_Value"] = df["Drug"].map(lambda x: fixed_values[x]["Salvage_Value"])
df["Shelf_Life"] = df["Drug"].map(lambda x: fixed_values[x]["Shelf_Life"])

# %%
df
# Out:
#      Day    Drug  Predicted_Demand  Unit_Cost  Salvage_Value  \
# 0      1  Drug A                43  33.690086       6.971516
# 1      2  Drug A                33  44.924573       1.045554
# 2      3  Drug A                19  26.249672       2.447272
# 3      4  Drug A                47  10.381741       5.938604
# 4      5  Drug A                12  37.096015       7.227057
# ..   ...     ...               ...        ...            ...
# 115   26  Drug D                27  12.273292       6.941776
# 116   27  Drug D                28  45.434938       3.519405
# 117   28  Drug D                41  32.289308       9.593788
# 118   29  Drug D                39   5.413867       7.641072
# 119   30  Drug D                48   9.566219       5.989186
#
#      Return_Prediction  Shelf_Life
# 0                    5          11
# 1                    6          13
# 2                    2          11
# 3                    9           9
# 4                    2          14
# ..                 ...         ...
# 115                  8          12
# 116                  3           5
# 117                  4          10
# 118                  3           5
# 119                  4           6
#
# [120 rows x 7 columns]

# %% [markdown]
# ## Optimization Model

# %%
# Gurobi Model
model = Model("Multi_Period_Medical_Inventory_Optimization")

# Decision Variables
Q = model.addVars(df.index, vtype=GRB.CONTINUOUS, name="OrderQty")  # Order quantity

# State Variables
I = model.addVars(df.index, vtype=GRB.CONTINUOUS, name="Inventory")  # Inventory level

# Auxiliary Variables (Derived)
Y = model.addVars(df.index, vtype=GRB.CONTINUOUS, name="Expired")   # Expired stock
S = model.addVars(df.index, vtype=GRB.CONTINUOUS, name="Stockout")  # Stockout

# Cost Coefficients
holding_cost = 2  # Cost per unit held
stockout_penalty = 50  # Cost per stockout
waste_penalty = 10  # Cost for expired stock

# Objective: Minimize Total Cost
model.setObjective(
    sum(df.loc[i, "Unit_Cost"] * Q[i] + 
        holding_cost * (I[i]) +
        stockout_penalty * S[i] + 
        waste_penalty * Y[i] - 
        df.loc[i, "Salvage_Value"] * df.loc[i, "Return_Prediction"]
        for i in df.index),
    GRB.MINIMIZE
)

# %%
# Constraints:
for i in df.index:
    # Inventory Balance Constraint
    if i >= T:  # Ensure we don't reference out-of-bounds indices
        continue
    model.addConstr(I[i+1] == I[i] + Q[i] + df.loc[i, "Return_Prediction"] - df.loc[i, "Predicted_Demand"] - Y[i], name=f"Inventory_Balance_{i}")

    model.addConstr(I[i+1] <= 100, name=f"Space_constraint{i}")
    
    # Expired Inventory Constraint
    model.addConstr(Y[i] <= I[i], name=f"Expiry_{i}")

    # Stockout Constraint
    model.addConstr(S[i] >= df.loc[i, "Predicted_Demand"] - I[i] - Q[i], name=f"Stockout_{i}")

# %%
# Solve Model
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[x86] - Darwin 24.3.0 24D81)
#
# CPU model: Intel(R) Core(TM) i7-8557U CPU @ 1.70GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 120 rows, 480 columns and 300 nonzeros
# Model fingerprint: 0xad4a45e8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 32 rows and 362 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 118 columns, 263 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.9063568e+03   1.848750e+02   0.000000e+00      0s
#       56    7.2073415e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 56 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  7.207341522e+03

# %%
# Store Results
df["Optimal_Order"] = [Q[i].x for i in df.index]
df["Inventory_Level"] = [I[i].x for i in df.index]
df["Expired_Stock"] = [Y[i].x for i in df.index]
df["Stockouts"] = [S[i].x for i in df.index]

# %%
df.head()
# Out:
#    Day    Drug  Predicted_Demand  Unit_Cost  Salvage_Value  Return_Prediction  \
# 0    1  Drug A                43  33.690086       6.971516                  5
# 1    2  Drug A                33  44.924573       1.045554                  6
# 2    3  Drug A                19  26.249672       2.447272                  2
# 3    4  Drug A                47  10.381741       5.938604                  9
# 4    5  Drug A                12  37.096015       7.227057                  2
#
#    Shelf_Life  Optimal_Order  Inventory_Level  Expired_Stock  Stockouts
# 0          11            0.0            138.0            0.0        0.0
# 1          13            0.0            100.0            0.0        0.0
# 2          11            0.0             73.0            0.0        0.0
# 3           9           82.0             56.0            0.0        0.0
# 4          14            0.0            100.0            0.0        0.0
